# %%
import pandas as pd

# %%
fp = "brut2025.txt"
df = pd.read_csv(fp,sep="|")
# Out:
# C:\Users\mpadmin\AppData\Local\Temp\ipykernel_13260\4141084686.py:2: DtypeWarning: Columns (18,23,24,26,28,29,31,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp,sep="|")

# %%
df.to_csv("2025.csv")

# %%
df=df.rename(columns= {"Type local":"Type_local"})

# %%
df["Type_local"]
# Out:
# 0                  NaN
# 1               Maison
# 2           Dépendance
# 3                  NaN
# 4                  NaN
#               ...
# 1387072    Appartement
# 1387073    Appartement
# 1387074     Dépendance
# 1387075            NaN
# 1387076            NaN
# Name: Type_local, Length: 1387077, dtype: object
